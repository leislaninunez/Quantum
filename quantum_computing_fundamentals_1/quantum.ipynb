# %% [markdown]
# # Superposition
#
# Superposition is a phenomena of multiple qubits exisisting in multiple states simultaneously. Superposition allows qubits to be in numerous states at once allowing multiple things to be true. Superpostion allows multiple possibilities to be true. Below is a demonstration of superposition in IBM quantum composer.
#
#
# ![image.png](attachment:image.png)

# %%
from qiskit import QuantumRegister, ClassicalRegister, QuantumCircuit
from numpy import pi

qreg_q = QuantumRegister(4, 'q')
creg_c = ClassicalRegister(4, 'c')
circuit = QuantumCircuit(qreg_q, creg_c)

circuit.h(qreg_q[0])
circuit.measure(qreg_q[0], creg_c[0])

# %% [markdown]
# # Entanglement
#
# Entanglement is when two or more qubits so are interlinked that no matter how far apart they are, they instantly affect each other. Entangled qubits share information with each other instantly. Changes within one qubit happen within the other connected qubit.
#
# ![Screenshot 2026-03-31 at 4.29.26 PM.png](<attachment:Screenshot 2026-03-31 at 4.29.26 PM.png>)

# %%
from qiskit import QuantumRegister, ClassicalRegister, QuantumCircuit
from numpy import pi

qreg_q = QuantumRegister(4, 'q')
creg_c = ClassicalRegister(4, 'c')
circuit = QuantumCircuit(qreg_q, creg_c)

circuit.h(qreg_q[0])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.measure(qreg_q[0], creg_c[0])
circuit.measure(qreg_q[1], creg_c[1])

circuit.draw()
# Out:
#      ┌───┐     ┌─┐
# q_0: ┤ H ├──■──┤M├───
#      └───┘┌─┴─┐└╥┘┌─┐
# q_1: ─────┤ X ├─╫─┤M├
#           └───┘ ║ └╥┘
# q_2: ───────────╫──╫─
#                 ║  ║
# q_3: ───────────╫──╫─
#                 ║  ║
# c: 4/═══════════╩══╩═
#                 0  1

# %% [markdown]
# # Noise in Quantum Computing
#
# Noise in Quantum is essentially anything that disrupts the fragile qubit's states. Noise can be caused by a multitude of things including heat and other enviornmental interferences. Noise disrupts entanglement and can cause the qubits to misbehave.
#
# ![Screenshot 2026-03-31 at 4.46.20 PM.png](<attachment:Screenshot 2026-03-31 at 4.46.20 PM.png>)

# %%
from qiskit import QuantumRegister, ClassicalRegister, QuantumCircuit
from numpy import pi

qreg_q = QuantumRegister(156, 'q')
creg_c = ClassicalRegister(4, 'c')
circuit = QuantumCircuit(qreg_q, creg_c)

circuit.rz(pi / 2, qreg_q[0])
circuit.sx(qreg_q[0])
circuit.rz(pi / 2, qreg_q[0])
circuit.rz(pi / 2, qreg_q[1])
circuit.sx(qreg_q[1])
circuit.rz(pi / 2, qreg_q[1])
circuit.cz(qreg_q[0], qreg_q[1])
circuit.rz(pi / 2, qreg_q[1])
circuit.sx(qreg_q[1])
circuit.rz(pi / 2, qreg_q[1])
circuit.measure(qreg_q[0], creg_c[0])
circuit.measure(qreg_q[1], creg_c[1])

# %% [markdown]
# # Constants
#
# ![Screenshot 2026-03-31 at 5.59.52 PM.png](<attachment:Screenshot 2026-03-31 at 5.59.52 PM.png>)
# ![Screenshot 2026-03-31 at 6.08.25 PM.png](<attachment:Screenshot 2026-03-31 at 6.08.25 PM.png>)
